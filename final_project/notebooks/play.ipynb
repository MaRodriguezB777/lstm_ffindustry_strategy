# %%
import pandas as pd

data = pd.read_csv('ff_industry_portfolios_daily_value/49_Industry_Portfolios_Daily.csv')
data = data.dropna()
data
# Out:
#            date  Agric  Food   Soda   Beer   Smoke  Toys   Fun    Books  \
# 0      19260701   0.56  -0.07 -99.99  -1.39   0.00  -1.44   0.62  -1.27
# 1      19260702   0.29   0.06 -99.99   0.78   0.70   1.46   0.03   0.00
# 2      19260706  -0.33   0.18 -99.99  -1.74   0.50  -0.96  -0.06   4.27
# 3      19260707   3.57  -0.15 -99.99  -1.73  -0.12  -0.49  -0.06  -4.10
# 4      19260708   0.30   1.12 -99.99  -0.15   0.30  -0.49   0.24   0.00
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25705  20240322  -1.21   0.14  -0.02  -0.32  -1.76  -1.26   0.25  -0.95
# 25706  20240325   0.76  -0.30  -0.35   0.40   0.42  -0.16  -0.06   0.24
# 25707  20240326   1.01   0.15   0.17  -0.04  -0.66   0.05   0.71  -0.10
# 25708  20240327   1.09   0.98   0.07   0.70   1.77   2.67  -1.22   1.23
# 25709  20240328   1.19   0.27   0.21   0.52  -0.46  -0.24  -0.43  -0.56
#
#        Hshld  ...  Boxes  Trans  Whlsl  Rtail  Meals  Banks  Insur  RlEst  \
# 0      -0.90  ...  -0.93   0.14   2.77  -0.02   0.27   0.59   0.47   0.81
# 1      -0.34  ...   1.07   0.07   0.00   0.01  -0.10   1.04  -0.03  -0.61
# 2      -1.20  ...   0.73  -0.20   0.77  -0.22  -0.67   0.45   0.31  -0.72
# 3      -0.22  ...   2.22   0.18  -3.21  -0.57  -1.08  -1.09   0.21   0.07
# 4      -0.01  ...  -0.39   0.46  -1.10  -0.38   0.33   0.99  -0.88  -0.36
# ...      ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25705  -0.18  ...  -0.13   0.00  -0.35  -0.37  -0.41  -1.59  -0.46  -1.62
# 25706  -0.86  ...   0.86  -0.71  -0.68  -0.27  -0.52  -0.35   0.06  -0.20
# 25707   0.22  ...   0.20  -1.51   0.10  -0.39   0.38  -0.01   0.54   0.29
# 25708   1.55  ...   1.18   1.23   1.20   0.93   0.86   1.46   0.86   1.51
# 25709   0.27  ...   0.70   0.50  -0.35   0.13  -0.09   0.63   0.26   0.77
#
#        Fin    Other
# 0       0.57  -1.66
# 1      -1.03   3.09
# 2       0.62   1.41
# 3       0.17   0.62
# 4      -1.10   0.98
# ...      ...    ...
# 25705  -1.50  -0.42
# 25706  -0.12  -0.51
# 25707  -0.04   0.42
# 25708   1.54   1.66
# 25709   0.26   0.22
#
# [25710 rows x 50 columns]

# %%
def normalize_column(column):
    invalid_val = -99.99
    
    # Exclude the value V from calculations
    filtered_values = column[column != invalid_val]
    mean = filtered_values.mean()
    std = filtered_values.std()

    if std <= 0:
        raise ValueError(f'Standard deviation {std} is zero or negative')
    
    column = column.apply(lambda x: (x - mean) / std if x != invalid_val else x)
    
    return column

normalized_df = data.apply(normalize_column)

# %%
normalized_df
# Out:
