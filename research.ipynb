# %%
# QuantBook Analysis Tool
# For more information see https://www.quantconnect.com/docs/research/overview
from AlgorithmImports import *
qb = QuantBook()
# Locally Lean installs free sample data, to download more data please visit https://www.quantconnect.com/docs/v2/lean-cli/datasets/downloading-data
qb.SetStartDate(2013, 10, 11)
spy = qb.AddEquity("SPY")
print(type(qb.Securities.Keys))
history = qb.History(["SPY"], 7, Resolution.Daily)

# # Indicator Analysis
# ema = qb.Indicator(ExponentialMovingAverage(10), spy.Symbol, 360, Resolution.Daily)
# ema.plot()
# Out:
# <class 'list'>

# %% [markdown]
# ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
# <hr>

# %%
history
# Out:
#                                   close        high         low        open  \
# symbol           time
# SPY R735QTJ8XC9X 2013-10-03  139.887132  139.969852  138.828321  139.250191
#                  2013-10-04  138.654610  139.746509  138.009397  139.605886
#                  2013-10-05  139.705149  139.845773  138.580163  138.753874
#                  2013-10-08  138.489171  139.341183  138.348548  138.497443
#                  2013-10-09  136.884411  138.654610  136.793419  138.513987
#                  2013-10-10  136.958858  137.479992  136.098574  137.165657
#                  2013-10-11  139.994668  139.994668  138.332004  138.406451
#
#                                   volume
# symbol           time
# SPY R735QTJ8XC9X 2013-10-03  105388449.0
#                  2013-10-04  185269969.0
#                  2013-10-05  102709468.0
#                  2013-10-08   98512576.0
#                  2013-10-09  186001485.0
#                  2013-10-10  173959239.0
#                  2013-10-11  190812660.0
